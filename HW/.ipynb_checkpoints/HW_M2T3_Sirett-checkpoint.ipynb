# %%
import  pandas  as pd
import  numpy  as np
import  matplotlib.pyplot  as plt

# %%
cen = pd.read_csv('census.csv')
cen
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %% [markdown]
# # Question 1
# How many observations are included in the census dataframe?
#
# There are 500 rows in the census dataframe

# %%
cen.shape
# Out:
# (500, 8)

# %% [markdown]
# # Question 2
# List the variables in the census dataframe
#
# The shape tells us that there are 8 columns:
# - census year
# - state
# - total family income
# - age
# - sex
# - race (general)
# - marital status
# - total personal income

# %% [markdown]
# # Question 3
# List each variable as either numerical or categorical
#
# Numerical: total family income, age, total personal income
#
# Categorical: census year, state, sex, race, marital status
