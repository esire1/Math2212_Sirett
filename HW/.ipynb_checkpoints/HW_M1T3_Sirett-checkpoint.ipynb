# %%
import  pandas  as pd
import  numpy  as np
import  matplotlib.pyplot  as plt

# %%
cen = pd.read_csv('census.csv')
cen
# Out:
#      TIME                            GEO  \
# 0    2000  European Union (28 countries)
# 1    2001  European Union (28 countries)
# 2    2002  European Union (28 countries)
# 3    2003  European Union (28 countries)
# 4    2004  European Union (28 countries)
# 5    2005  European Union (28 countries)
# 6    2006  European Union (28 countries)
# 7    2007  European Union (28 countries)
# 8    2008  European Union (28 countries)
# 9    2009  European Union (28 countries)
# 10   2010  European Union (28 countries)
# 11   2011  European Union (28 countries)
# 12   2000  European Union (27 countries)
# 13   2001  European Union (27 countries)
# 14   2002  European Union (27 countries)
# 15   2003  European Union (27 countries)
# 16   2004  European Union (27 countries)
# 17   2005  European Union (27 countries)
# 18   2006  European Union (27 countries)
# 19   2007  European Union (27 countries)
# 20   2008  European Union (27 countries)
# 21   2009  European Union (27 countries)
# ...

# %% [markdown]
# # Question 1
# When appending new rows to a dataframe, the parameters 'ignore_index' and 'sort' are useful in the process. 'ignore_index' tells the computer when to use index labels. While 'sort' sorts all of the numbers and helps to keep the data set organized.

# %% [markdown]
# # Question 2

# %% [markdown]
# The columns are census year, state fips code, totaly family icome, age, sex, race general, marital status, and totaly personal income. This is state by the code: "census_year","state_fips_code","total_family_income","age","sex",
# "race_general","marital_status","total_personal_income"

# %% [markdown]
# # Question 3

# %%
cen [19:46]

# %%
cen [23:27][['age','sex','race_general']]

# %%
cen [45][['census_year' , 'state_fips_code' , 'total_family_income' , 'age' , 'sex' , 'race_general' , 'marital_status' , 'total_personal_income']]

# %%
cen [['census_year','state_fips_code']]

# %% [markdown]
# # Question 4

# %%
PrintAge = cen['age']
PrintAge

# %% [markdown]
# # Question 5

# %%
cen_sus = cen

cen_sus.drop(['census_year'])
cen_sus['family_minus_personal_income'] = cen_sus['total_family_income'-'total_personal_income']
cen_sus['family_income_squared'] = cen_sus['total_family_income']**2
cen_sus

# %% [markdown]
# # Question 6
