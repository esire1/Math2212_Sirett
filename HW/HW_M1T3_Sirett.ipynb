# %%
import  pandas  as pd
import  numpy  as np
import  matplotlib.pyplot  as plt

# %%
cen = pd.read_csv('census.csv')
cen
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %% [markdown]
# # Question 1
# When appending new rows to a dataframe, the parameters 'ignore_index' and 'sort' are useful in the process. 'ignore_index' tells the computer when to use index labels. While 'sort' sorts all of the numbers and helps to keep the data set organized.

# %% [markdown]
# # Question 2

# %% [markdown]
# *COMMENT: I don't think that code will tell you the columns. Maybe this is a partial answer? 1/2 pts*

# %% [markdown]
# The columns are census year, state fips code, totaly family icome, age, sex, race general, marital status, and totaly personal income. This is state by the code: "census_year","state_fips_code","total_family_income","age","sex",
# "race_general","marital_status","total_personal_income"

# %% [markdown]
# # Question 3

# %%
cen [19:46]
# Out:
#     census_year state_fips_code  total_family_income  age     sex  \
# 19         2000         Florida              43950.0   69  Female
# 20         2000         Florida              49000.0   31    Male
# 21         2000         Florida              31600.0   80  Female
# 22         2000         Florida              50090.0    2    Male
# 23         2000         Florida              64800.0   47    Male
# 24         2000         Florida              90000.0   12    Male
# 25         2000         Florida              38320.0   47    Male
# 26         2000         Florida             103700.0    8  Female
# 27         2000         Florida                  0.0   67    Male
# 28         2000         Florida              70700.0   17  Female
# 29         2000         Florida              64800.0   69  Female
# 30         2000         Florida              60000.0   55    Male
# 31         2000         Florida             118100.0   18  Female
# ...

# %%
cen [23:27][['age','sex','race_general']]
# Out:
#     age     sex race_general
# 23   47    Male        White
# 24   12    Male        White
# 25   47    Male        White
# 26    8  Female        White

# %%
cen[45:46]
# Out:
#     census_year state_fips_code  total_family_income  age     sex  \
# 45         2000        New York              68020.0    2  Female
#
#    race_general        marital_status  total_personal_income
# 45      Chinese  Never married/single                    NaN

# %%
cen [['census_year','state_fips_code']]
# Out:
#      census_year state_fips_code
# 0           2000         Florida
# 1           2000         Florida
# 2           2000         Florida
# 3           2000         Florida
# 4           2000         Florida
# 5           2000         Florida
# 6           2000         Florida
# 7           2000         Florida
# 8           2000         Florida
# 9           2000         Florida
# 10          2000         Florida
# 11          2000         Florida
# 12          2000         Florida
# 13          2000         Florida
# 14          2000         Florida
# 15          2000         Florida
# 16          2000         Florida
# 17          2000         Florida
# 18          2000         Florida
# 19          2000         Florida
# 20          2000         Florida
# 21          2000         Florida
# 22          2000         Florida
# 23          2000         Florida
# 24          2000         Florida
# 25          2000         Florida
# 26          2000         Florida
# ...

# %% [markdown]
# # Question 4

# %%
PrintAge = cen[['age']]
PrintAge
# Out:
#      age
# 0     44
# 1     20
# 2     20
# 3      6
# 4     55
# 5     43
# 6     60
# 7     47
# 8     54
# 9     58
# 10    33
# 11    51
# 12    62
# 13     8
# 14    25
# 15    44
# 16    28
# 17     1
# 18    31
# 19    69
# 20    31
# 21    80
# 22     2
# 23    47
# 24    12
# 25    47
# 26     8
# 27    67
# 28    17
# 29    69
# ..   ...
# 470    1
# 471   29
# 472   61
# 473   36
# 474   25
# 475   41
# 476    9
# 477   10
# 478   13
# 479    3
# 480   15
# 481   32
# 482   68
# 483   32
# 484   32
# 485   24
# 486   18
# 487   41
# 488    6
# 489   38
# 490   43
# 491   76
# 492   24
# 493   36
# 494    5
# 495   68
# 496   12
# 497   60
# 498   60
# 499   47
#
# [500 rows x 1 columns]

# %% [markdown]
# # Question 5

# %% [markdown]
# *COMMENT: it looks like you added columns instead of rows.  But you did that correctly, so full credit*

# %%
cen_sus = cen

cen_sus.drop(['census_year'], axis=1)
# Out:
#     state_fips_code  total_family_income  age     sex     race_general  \
# 0           Florida              14550.0   44    Male  Two major races
# 1           Florida              22800.0   20  Female            White
# 2           Florida                  0.0   20    Male            Black
# 3           Florida              23000.0    6  Female            White
# 4           Florida              48000.0   55    Male            White
# 5           Florida              74000.0   43  Female            White
# 6           Florida              23000.0   60  Female            White
# 7           Florida              74000.0   47  Female            White
# 8           Florida              60000.0   54  Female            Black
# 9           Florida              14600.0   58  Female            White
# 10          Florida                  0.0   33  Female            White
# 11          Florida              37000.0   51  Female            White
# ...

# %%
cen_sus['family_minus_personal_income'] = cen_sus['total_family_income'] - cen_sus ['total_personal_income']
cen_sus['family_income_squared'] = cen_sus['total_family_income']**2
cen_sus
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %% [markdown]
# # Question 6

# %%
cen[cen['state_fips_code']=="Connecticut"]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 274         2000     Connecticut                  NaN   56  Female
# 275         2000     Connecticut                  0.0   52    Male
# 276         2000     Connecticut              80100.0   16    Male
# 277         2000     Connecticut             129300.0   32  Female
#
#     race_general          marital_status  total_personal_income  \
# 274        Black    Never married/single                 3600.0
# 275        White                Divorced                51000.0
# 276        White    Never married/single                    0.0
# 277        White  Married/spouse present                34300.0
#
#      family_minus_personal_income  family_income_squared
# 274                           NaN                    NaN
# 275                      -51000.0           0.000000e+00
# 276                       80100.0           6.416010e+09
# 277                       95000.0           1.671849e+10

# %%
cen [cen['total_family_income']<75000]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %%
cen [(cen['age']>30)&cen['age']<50]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %%
cen[(cen['race_general']=="White")|(cen['race_general']=="Black")]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# 13          2000         Florida             113000.0    8    Male
# ...

# %% [markdown]
# # Question 7

# %%
cen[cen['total_personal_income'].isnull()]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 3           2000         Florida              23000.0    6  Female
# 13          2000         Florida             113000.0    8    Male
# 17          2000         Florida              48000.0    1    Male
# 22          2000         Florida              50090.0    2    Male
# 24          2000         Florida              90000.0   12    Male
# 26          2000         Florida             103700.0    8  Female
# 37          2000         Florida               6000.0    2    Male
# 44          2000        New York              13000.0    1    Male
# 45          2000        New York              68020.0    2  Female
# 49          2000        New York              12400.0    7    Male
# 51          2000        New York              65000.0    1  Female
# 54          2000        New York              81710.0   14    Male
# 59          2000        New York             168200.0    6  Female
# ...

# %% [markdown]
# # Question 8

# %%
cen.isnull()
# Out:
#      census_year  state_fips_code  total_family_income    age    sex  \
# 0          False            False                False  False  False
# 1          False            False                False  False  False
# 2          False            False                False  False  False
# 3          False            False                False  False  False
# 4          False            False                False  False  False
# 5          False            False                False  False  False
# 6          False            False                False  False  False
# 7          False            False                False  False  False
# 8          False            False                False  False  False
# 9          False            False                False  False  False
# 10         False            False                False  False  False
# 11         False            False                False  False  False
# 12         False            False                False  False  False
# ...

# %% [markdown]
# cen.isnull() represents all data points where no entry was given
